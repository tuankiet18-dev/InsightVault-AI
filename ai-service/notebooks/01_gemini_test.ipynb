# %% [markdown]
# # InsightVault AI - Thử nghiệm Gemini API
# Notebook này dùng để test luồng prompt, API Gemini, hoặc Langchain trước khi đưa logic vào FastAPI production.

# %%
import os
import google.generativeai as genai
from dotenv import load_dotenv

# Load biến môi trường từ file .env (cùng thư mục với notebook hoặc ở root ai-service)
load_dotenv()

api_key = os.getenv("GEMINI_API_KEY", "YOUR_API_KEY_HERE")
genai.configure(api_key=api_key)

model = genai.GenerativeModel('gemini-1.5-flash')
print("Đã cấu hình Gemini model thành công!")

# response = model.generate_content("Xin chào, bạn có thể giúp gì cho tôi?")
# print(response.text)
